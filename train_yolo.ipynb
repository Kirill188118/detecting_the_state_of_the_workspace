# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
result = model.train(data = 'my_dataset_yolo/data.yaml', epochs=100, imgsz=640)
# Out:
# ...
# Ultralytics 8.4.48  Python-3.12.10 torch-2.11.0+cpu CPU (AMD Ryzen 3 4300U with Radeon Graphics)
# ...
